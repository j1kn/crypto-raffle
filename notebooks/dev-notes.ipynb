# %% [markdown]
# # Dev Notes
#
# - Re-enabled Wagmi reconnectOnMount to persist wallet connection across pages.
# - Updated raffle payment flow to auto-switch to Ethereum mainnet for ETH raffles using useSwitchChain.
